# %%
fetch_qry = """
SELECT *
FROM dev.stg_polls P
INNER JOIN dev.stg_meeting M ON P.meeting_id = M.meeting_id

"""
# Out:
#   Cell In[1], line 1
#     fetch_qry = """
#                 ^
# SyntaxError: incomplete input
